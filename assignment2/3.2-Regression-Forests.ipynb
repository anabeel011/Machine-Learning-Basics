# %%
# %%javascript
# IPython.notebook.clear_all_output();

# %% [markdown]
# # Supervised Learning In-Depth: Random Forests

# %% [markdown]
# Previously we saw a powerful discriminative classifier, **Support Vector Machines**.
# Here we'll take a look at motivating another powerful algorithm. This one is a *non-parametric* algorithm called **Random Forests**.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

plt.style.use('seaborn')

# %% [markdown]
# ## Motivating Random Forests: Decision Trees

# %% [markdown]
# Random forests are an example of an *ensemble learner* built on decision trees.
# For this reason we'll start by discussing decision trees themselves.
#
# Decision trees are extremely intuitive ways to classify or label objects: you simply ask a series of questions designed to zero-in on the classification:

# %%
import fig_code
fig_code.plot_example_decision_tree()
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# The binary splitting makes this extremely efficient.
# As always, though, the trick is to *ask the right questions*.
# This is where the algorithmic process comes in: in training a decision tree classifier, the algorithm looks at the features and decides which questions (or "splits") contain the most information.
#
# ### Creating a Decision Tree
#
# Here's an example of a decision tree classifier in scikit-learn. We'll start by defining some two-dimensional labeled data:

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=300, centers=4,
                  random_state=0, cluster_std=1.0)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow');

# %% [markdown]
# We have some convenience functions in the repository that help

# %%
from fig_code import visualize_tree, plot_tree_interactive

# %% [markdown]
# Now using IPython's ``interact`` (available in IPython 2.0+, and requires a live kernel) we can view the decision tree splits:

# %%
plot_tree_interactive(X, y);
# Out:
# interactive(children=(IntSlider(value=1, description='depth', max=5, min=1), Output()), _dom_classes=('widget-…

# %% [markdown]
# Notice that at each increase in depth, every node is split in two **except** those nodes which contain only a single class.
# The result is a very fast **non-parametric** classification, and can be extremely useful in practice.
#
# **Question: Do you see any problems with this?**
# Ans: there are still some points wrongly classified, this can be corrected by further increasing depth, but that will lead to creation of too many splits, which can lead to over-fitting.

# %% [markdown]
# ### Decision Trees and over-fitting
#
# One issue with decision trees is that it is very easy to create trees which **over-fit** the data. That is, they are flexible enough that they can learn the structure of the noise in the data rather than the signal! For example, take a look at two trees built on two subsets of this dataset:

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()

plt.figure()
visualize_tree(clf, X[:200], y[:200], boundaries=False)
plt.figure()
visualize_tree(clf, X[-200:], y[-200:], boundaries=False)

# %% [markdown]
# The details of the classifications are completely different! That is an indication of **over-fitting**: when you predict the value for a new point, the result is more reflective of the noise in the model rather than the signal.

# %% [markdown]
# ## Ensembles of Estimators: Random Forests
#
# One possible way to address over-fitting is to use an **Ensemble Method**: this is a meta-estimator which essentially averages the results of many individual estimators which over-fit the data. Somewhat surprisingly, the resulting estimates are much more robust and accurate than the individual estimates which make them up!
#
# One of the most common ensemble methods is the **Random Forest**, in which the ensemble is made up of many decision trees which are in some way perturbed.
#
# There are volumes of theory and precedent about how to randomize these trees, but as an example, let's imagine an ensemble of estimators fit on subsets of the data. We can get an idea of what these might look like as follows:

# %%
def fit_randomized_tree(random_state=0):
    X, y = make_blobs(n_samples=300, centers=4,
                      random_state=0, cluster_std=2.0)
    clf = DecisionTreeClassifier(max_depth=15)
    
    rng = np.random.RandomState(random_state)
    i = np.arange(len(y))
    rng.shuffle(i)
    visualize_tree(clf, X[i[:250]], y[i[:250]], boundaries=False, #use the first 250 / 300 data points after shuffling
                   xlim=(X[:, 0].min(), X[:, 0].max()),
                   ylim=(X[:, 1].min(), X[:, 1].max()))
    
from ipywidgets import interact
interact(fit_randomized_tree, random_state=(0, 100));
# Out:
# interactive(children=(IntSlider(value=0, description='random_state'), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# See how the details of the model change as a function of the sample, while the larger characteristics remain the same!
# The random forest classifier will do something similar to this, but use a combined version of all these trees to arrive at a final answer:

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, random_state=0)
visualize_tree(clf, X, y, boundaries=False);

# %% [markdown]
# By averaging over 100 randomly perturbed models, we end up with an overall model which is a much better fit to our data!
#
# *(Note: above we randomized the model through sub-sampling (sampling rows)... Random Forests use more sophisticated means of randomization (esp. sampling columns), which you can read about in, e.g. the [scikit-learn documentation](http://scikit-learn.org/stable/modules/ensemble.html#forest)*)

# %% [markdown]
# ## Quick Example: Moving to Regression
#
# Above we were considering random forests within the context of classification.
# Random forests can also be made to work in the case of regression (that is, continuous rather than categorical variables). The estimator to use for this is ``sklearn.ensemble.RandomForestRegressor``.
#
# Let's quickly demonstrate how this can be used:

# %%
from sklearn.ensemble import RandomForestRegressor

x = 10 * np.random.rand(100)

def model(x, sigma=0.3):
    fast_oscillation = np.sin(5 * x)
    slow_oscillation = np.sin(0.5 * x)
    noise = sigma * np.random.randn(len(x))

    return slow_oscillation + fast_oscillation + noise

y = model(x)
plt.errorbar(x, y, 0.3, fmt='o');

# %%
xfit = np.linspace(0, 10, 1000)
yfit = RandomForestRegressor(100).fit(x[:, None], y).predict(xfit[:, None])
ytrue = model(xfit, 0)

plt.errorbar(x, y, 0.3, fmt='o')
plt.plot(xfit, yfit, '-r');
plt.plot(xfit, ytrue, '-k', alpha=0.5);

# %% [markdown]
# As you can see, the non-parametric random forest model is flexible enough to fit the multi-period data, without us even specifying a multi-period model!

# %% [markdown]
# ## Example: Random Forest for Classifying Digits
#
# We previously saw the **hand-written digits** data. Let's use that here to test the efficacy of the SVM and Random Forest classifiers.

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
X = digits.data
y = digits.target
print(X.shape)
print(y.shape)
# Out:
# (1797, 64)
# (1797,)

# %% [markdown]
# To remind us what we're looking at, we'll visualize the first few data points:

# %%
# set up the figure
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# plot the digits: each image is 8x8 pixels
for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(digits.images[i], cmap=plt.cm.binary, interpolation='nearest')
    
    # label the image with the target value
    ax.text(0, 7, str(digits.target[i]))

# %% [markdown]
# We can quickly classify the digits using a decision tree as follows:

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=0)
clf = DecisionTreeClassifier(max_depth=11)
clf.fit(Xtrain, ytrain)
ypred = clf.predict(Xtest)

# %% [markdown]
# We can check the accuracy of this classifier:

# %%
metrics.accuracy_score(ypred, ytest)
# Out:
# 0.8444444444444444

# %% [markdown]
# and for good measure, plot the confusion matrix:

# %%
plt.imshow(metrics.confusion_matrix(ypred, ytest),
           interpolation='nearest', cmap=plt.cm.binary)
plt.grid(False)
plt.colorbar()
plt.xlabel("predicted label")
plt.ylabel("true label");

# %% [markdown]
# ### Exercise
# 1. Repeat this classification task with ``sklearn.ensemble.RandomForestClassifier``.  How does the ``max_depth``, ``max_features``, and ``n_estimators`` affect the results?
# 2. (For graduate students only) Try this classification with ``sklearn.svm.SVC``, adjusting ``kernel``, ``C``, and ``gamma``. Which classifier performs optimally?
# 3. Try a few sets of parameters for each model and check the F1 score (``sklearn.metrics.f1_score``) on your results. What's the best F1 score you can reach?
# 4. (For PhD students only) Try the same procedure using ``sklearn.model_selection.GridSearchCV``, for which you can self-study from the Internet, such as https://scikit-learn.org/stable/auto_examples/model_selection/plot_grid_search_digits.html

# %%
# Using sklearn.ensemble.RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_digits
digits = load_digits()
digits.keys()

X = digits.data
y = digits.target
print(X.shape)
print(y.shape)

# set up the figure
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# plot the digits: each image is 8x8 pixels
for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(digits.images[i], cmap=plt.cm.binary, interpolation='nearest')
    
    # label the image with the target value
    ax.text(0, 7, str(digits.target[i]))
# Out:
# (1797, 64)
# (1797,)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=0)
clf = RandomForestClassifier(n_estimators = 100)

# clf2 uses 50 estimators. This is to compare what n_estimators does
clf2 = RandomForestClassifier(n_estimators = 50)

# max_depth default value is none. The tree fully expands when no vale is given
clf3 = RandomForestClassifier(max_depth=30)

# max_features has default value auto = sqrt(n_features)
clf4 = RandomForestClassifier(max_features = 10)

clf.fit(Xtrain, ytrain)
clf2.fit(Xtrain, ytrain)
clf3.fit(Xtrain, ytrain)
clf4.fit(Xtrain, ytrain)

ypred = clf.predict(Xtest)
ypred2 = clf2.predict(Xtest)
ypred3 = clf3.predict(Xtest)
ypred4 = clf4.predict(Xtest)

print(metrics.accuracy_score(ypred, ytest))
print(metrics.accuracy_score(ypred2, ytest))
print(metrics.accuracy_score(ypred3, ytest))
print(metrics.accuracy_score(ypred4, ytest))


plt.imshow(metrics.confusion_matrix(ypred, ytest),
           interpolation='nearest', cmap=plt.cm.binary)

#plt.imshow(metrics.confusion_matrix(ypred2, ytest),
           #interpolation='nearest', cmap=plt.cm.binary)
plt.grid(False)
plt.colorbar()
plt.xlabel("predicted label")
plt.ylabel("true label");

# this has better accuracy (0.98 compared to previous 0.8444)
# below it can be seen that accuracy is low when n_estimators is less
# by changing the arguments of the model accuracy changes, these arguments can be used to limit the tree depth
#  estimators and features to be extracted, thus giving more control to not over-fit
# Out:
# 0.9755555555555555
# 0.9777777777777777
# 0.9844444444444445
# 0.9755555555555555

# %%
# Using SVC

# linear kernel
from sklearn.svm import SVC  # "Support Vector Classifier"

# linear kernel with default values
clfsvclinear = SVC(kernel='linear')
clfsvclinear.fit(Xtrain, ytrain)

# linear kernel with different c and gamma
clfsvclineard = SVC(kernel='linear', C=0.5, gamma='auto')
clfsvclineard.fit(Xtrain, ytrain)

# poly kernel with default values
clfsvcpoly = SVC(kernel='poly')
clfsvcpoly.fit(Xtrain, ytrain)

# poly kernel with different C, gamma and degree values
clfsvcpolyd = SVC(kernel='poly', C=0.5, gamma='auto', degree=5)
clfsvcpolyd.fit(Xtrain, ytrain)

# rbf kernel with default values
clfsvcrbf = SVC(kernel='rbf')
clfsvcrbf.fit(Xtrain, ytrain)

# rbf kernel with different C and gamma values
clfsvcrbfd = SVC(kernel='rbf', C=0.5, gamma='auto')
clfsvcrbfd.fit(Xtrain, ytrain)

# fitting
clfsvclinear.fit(Xtrain, ytrain)
clfsvcpoly.fit(Xtrain, ytrain)
clfsvcrbf.fit(Xtrain, ytrain)
clfsvclineard.fit(Xtrain, ytrain)
clfsvcpolyd.fit(Xtrain, ytrain)
clfsvcrbfd.fit(Xtrain, ytrain)

ypredlinear = clfsvclinear.predict(Xtest)
ypredpoly = clfsvcpoly.predict(Xtest)
ypredrbf = clfsvcrbf.predict(Xtest)
ypredlineard = clfsvclineard.predict(Xtest)
ypredpolyd = clfsvcpolyd.predict(Xtest)
ypredrbfd = clfsvcrbfd.predict(Xtest)


print("Accuracy for linear with default values")
print(metrics.accuracy_score(ypredlinear, ytest))
print("f1 score for linear with default values")
print(metrics.f1_score(ytest, ypredlinear, average='micro')) # using micro as it gives average as whole
print("\nAccuracy for linear with different C and Gamma")
print(metrics.accuracy_score(ypredlineard, ytest))
print("f1 score for linear with different C and Gamma")
print(metrics.f1_score(ytest, ypredlineard, average = 'micro'))

print("\n")

print("Accuracy for poly with default values")
print(metrics.accuracy_score(ypredpoly, ytest))
print("f1 score for poly with default values")
print(metrics.f1_score(ytest, ypredpoly, average='micro'))
print("\nAccuracy for poly with different degree, C and Gamma")
print(metrics.accuracy_score(ypredpolyd, ytest))
print("f1 score for poly with different degree, C and Gamma")
print(metrics.f1_score(ytest, ypredpoly, average='micro'))

print("\n")

print("Accuracy for rbf with default values")
print(metrics.accuracy_score(ypredrbf, ytest))
print("f1 score for poly with default values")
print(metrics.f1_score(ytest, ypredrbf, average='micro'))
print("\nAccuracy for rbf with different C and Gamma")
print(metrics.accuracy_score(ypredrbfd, ytest))
print("f1 score for poly with different C and Gamma")
print(metrics.f1_score(ytest, ypredrbf, average='micro'))

# resluts below show that rbf performs the best, followed by poly and linear
# That is quite understandale as linear is the most inefficient way of classification
# Mostly data can not be classified in a linear fashion, there is a lot of room for error
# Out:
# Accuracy for linear with default values
# 0.9711111111111111
# f1 score for linear with default values
# 0.9711111111111111
#
# Accuracy for linear with different C and Gamma
# 0.9711111111111111
# f1 score for linear with different C and Gamma
# 0.9711111111111111
#
#
# Accuracy for poly with default values
# 0.9888888888888889
# f1 score for poly with default values
# 0.9888888888888889
#
# Accuracy for poly with different degree, C and Gamma
# 0.9822222222222222
# f1 score for poly with different degree, C and Gamma
# 0.9888888888888889
#
#
# Accuracy for rbf with default values
# 0.9911111111111112
# f1 score for poly with default values
# 0.9911111111111112
#
# Accuracy for rbf with different C and Gamma
# 0.08888888888888889
# f1 score for poly with different C and Gamma
# 0.9911111111111112
